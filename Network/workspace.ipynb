# %%
import zipfile
import os

# 基本解压
def unzip_file(zip_path, extract_path):
    """
    解压ZIP文件到指定目录
    
    Args:
        zip_path: ZIP文件路径
        extract_path: 解压目标目录
    """
    # 确保目标目录存在
    os.makedirs(extract_path, exist_ok=True)
    
    # 解压文件
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    
    print(f"文件已解压到: {extract_path}")

# 使用示例
unzip_file('/openbayes/input/input0/TB.zip', './data')

# %%
import train
args = 1
train.main(args)

# %%
import inference
inference.main()
